# %% [markdown]
# # Этап 1. Подготовка данных

# %% [markdown]
# Загрузим данные

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("data/dataset1.csv")

# %%
dataset.head()
# Out:
#    Unnamed: 0   PRODUCT  CATEGORY_ID  BRAND_ID  \
# 0           0  30024724      2060202      1900
# 1           1  30024724      2060202      1900
# 2           2  30024725      2060202      1900
# 3           3  30024727      2060101      1900
# 4           4  30024727      2060101      1900
#
#                                 CATEGORY_NAME            BRAND_NAME    TYPE  \
# 0  PRINTERS LASER                              Kyocera               REVIEW
# 1  PRINTERS LASER                              Kyocera               REVIEW
# 2  PRINTERS LASER                              Kyocera               REVIEW
# 3  ALL-IN-ONE LASER                            Kyocera               REVIEW
# 4  ALL-IN-ONE LASER                            Kyocera               REVIEW
#
#                                              SUBJECT  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  С такой вроде бы навороченной техникой все смо...
# 4                                                NaN
#
#                                                 TEXT        POSTED_DATE  \
# 0  Что особенно ценно - при профилактике принтера...  23.10.16 22:26:00
# 1  Он у нас три месяца в офисе стоит уже - большо...  17.04.16 11:17:42
# 2  Просто небо и земля с тем принтером, который у...  15.04.16 20:22:47
# 3  У нас в кабинете недавно его поставили. Первое...  18.04.16 20:01:57
# 4  Очень многофункциональная штука.  Есть все нео...  23.04.16 12:03:39
#
#    RATING                                           BENEFITS  \
# 0     5.0  хорошая скорость печати, двусторонняя печать, ...
# 1     5.0                                                NaN
# 2     4.0                                                NaN
# 3     5.0                                                NaN
# 4     5.0                                                NaN
#
#                                            DRAWBACKS  RECOMMENDED  \
# 0  Рядом "на стол" не поставишь, место много зани...          1.0
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3                                                NaN          NaN
# 4                                                NaN          NaN
#
#    LIKES_COUNT  DISLIKES_COUNT
# 0          2.0             0.0
# 1          0.0             2.0
# 2          0.0             1.0
# 3          0.0             0.0
# 4          1.0             0.0

# %% [markdown]
# ## Предобработка текстов
#
# Определим функцию, применяющую к тексту следующие преобразования:
#
# - использование нижнего регистра
# - удаление знаков препинания (потребуется в следующих шагах)
# - токенизация
# - добавление POS-тегов (потребуются при фильтрации текстов)

# %%
from pymorphy2 import MorphAnalyzer
from nltk.tokenize import word_tokenize
from functools import lru_cache


morph = MorphAnalyzer()


@lru_cache(20000)
def morph_parse(token):
    return morph.parse(token)


def text_conversion(text):
    tokens = [token for token in word_tokenize(text.lower()) if len(token) > 0]
    result = []
    for token in tokens:
        morph = morph_parse(token)
        if len(morph) > 0:
            if morph[0].tag.POS is not None:
                result.append(morph[0])
    return " ".join(map(lambda morph: "{0}_{1}".format(morph.word, morph.tag.POS), result))


def texts_conversion(texts, message_each=100):
    result = []
    for i, text in enumerate(texts):
        if i % message_each == 0:
            print("Converting text", i + 1)
        result.append(text_conversion(text))
    return result

# %% [markdown]
# Проверим функцию над коллекцией из текстов первой пары отзывов

# %%
texts_conversion(dataset.loc[0:1, "TEXT"])
# Out:
# Converting text 1
# ['что_CONJ особенно_ADVB ценно_ADJS при_PREP профилактике_NOUN принтера_NOUN можно_PRED вычистить_INFN блок_NOUN печати_NOUN от_PREP бумажной_ADJF пыли_NOUN все_ADJF запчасти_NOUN снимаются_VERB каждую_ADJF можно_PRED отдельно_ADVB почистить_INFN щёткой_NOUN и_CONJ пропылесосить_INFN и_CONJ будет_VERB как_CONJ новая_ADJF меньше_COMP пыли_NOUN меньше_COMP еёдавления_NOUN на_PREP фотобарабан_NOUN меньше_COMP давления_NOUN на_PREP фотобарабан_NOUN меньше_COMP его_NPRO стирание_NOUN и_CONJ соответственно_ADVB больше_COMP срок_NOUN службы_NOUN фотовала_NOUN у_PREP нас_NPRO в_PREP организации_NOUN фотовал_NOUN прошёл_VERB двойной_ADJF срок_NOUN службы_NOUN бумагау_NOUN использовыали_VERB отечественную_ADJF ксероксную_ADJF просто_PRCL чистили_VERB ругулярно_ADJS и_CONJ ещё_ADVB один_ADJF мент_NOUN для_PREP повышения_NOUN срока_NOUN службы_NOUN аппарата_NOUN задействуйте_VERB в_PREP нем_ADJS все_ADJF лотки_NOUN для_PREP бумаги_NOUN если_CONJ одновременно_ADVB используете_VERB лотка_NOUN с_PREP листами_NOUN сразу_ADVB загружайте_VERB по_PREP листов_NOUN в_PREP оба_NUMR пачка_NOUN бумаги_NOUN пополам_ADVB и_CONJ один_ADJF лоток_NOUN задвигаете_VERB в_PREP принтер_NOUN до_PREP конца_NOUN а_CONJ второй_ADJF недодвигаете_VERB на_PREP см_NOUN и_CONJ оставляете_VERB в_PREP таком_ADJF виде_NOUN когда_CONJ бумага_NOUN заканчивается_VERB в_PREP первом_NOUN задвигаете_VERB до_PREP конца_NOUN второй_ADJF печать_NOUN продолжается_VERB а_CONJ тем_CONJ временем_NOUN в_PREP первый_ADJF лоток_NOUN можно_PRED загрузить_INFN новую_ADJF партию_NOUN листов_NOUN бумаги_NOUN так_CONJ контролируется_VERB процесс_NOUN загруженности_NOUN лотков_NOUN и_CONJ экономится_VERB время_NOUN простоя_NOUN принтера_NOUN и_CONJ меньше_COMP стираются_VERB подборные_ADJF ролики_NOUN на_PREP лотках_NOUN',
#  'он_NPRO у_PREP нас_NPRO три_NUMR месяца_NOUN в_PREP офисе_NOUN стоит_VERB уже_ADVB большого_ADJF внимания_NOUN к_PREP себе_NPRO не_PRCL требует_VERB среднюю_ADJF дневную_ADJF нагрузку_NOUN в_PREP листов_NOUN выдерживает_VERB при_PREP печати_NOUN достойно_ADVB не_PRCL полосит_NOUN странцицы_NOUN бумагу_NOUN не_PRCL жуёт_VERB только_PRCL пару_NOUN раз_NOUN листы_NOUN затянул_VERB да_PRCL и_CONJ то_CONJ из-за_PREP того_ADJF что_CONJ они_NPRO в_PREP лотке_NOUN криво_ADJS лежали_VERB ещё_PRCL в_PREP него_NPRO листы_NOUN можно_PRED загружать_INFN выручает_VERB если_CONJ таблицу_NOUN большую_ADJF для_PREP собрания_NOUN надо_PRED распечатать_INFN в_PREP общем_ADJF нормально_ADJS выполняет_VERB свои_ADJF функции_NOUN можно_PRED производителю_NOUN пятёрку_NOUN поставить_INFN твёрдую_ADJF']

# %% [markdown]
# Заполним и модифицируем текстовые поля

# %%
dataset["BENEFITS_FILLED"] = dataset["BENEFITS"].fillna("")
dataset["DRAWBACKS_FILLED"] = dataset["DRAWBACKS"].fillna("")
dataset["TEXT_FILLED"] = dataset["TEXT"].fillna("")

# %%
dataset["TEXT_CONVERTED"] = texts_conversion(dataset["TEXT_FILLED"])
dataset["BENEFITS_CONVERTED"] = texts_conversion(dataset["BENEFITS_FILLED"])
dataset["DRAWBACKS_CONVERTED"] = texts_conversion(dataset["DRAWBACKS_FILLED"])
# Out:
# Converting text 1
# Converting text 101
# Converting text 201
# Converting text 301
# Converting text 401
# Converting text 501
# Converting text 601
# Converting text 701
# Converting text 801
# Converting text 901
# Converting text 1001
# Converting text 1101
# Converting text 1201
# Converting text 1301
# Converting text 1401
# Converting text 1501
# Converting text 1601
# Converting text 1701
# Converting text 1801
# Converting text 1901
# Converting text 2001
# Converting text 2101
# Converting text 2201
# Converting text 2301
# Converting text 2401
# Converting text 2501
# Converting text 2601
# Converting text 2701
# Converting text 2801
# Converting text 2901
# Converting text 3001
# Converting text 3101
# Converting text 3201
# Converting text 3301
# Converting text 3401
# Converting text 3501
# Converting text 3601
# Converting text 3701
# Converting text 3801
# Converting text 3901
# Converting text 4001
# Converting text 4101
# Converting text 4201
# Converting text 4301
# Converting text 4401
# Converting text 4501
# Converting text 4601
# Converting text 4701
# Converting text 4801
# Converting text 4901
# Converting text 5001
# Converting text 5101
# Converting text 5201
# Converting text 5301
# Converting text 5401
# Converting text 5501
# Converting text 5601
# Converting text 5701
# Converting text 5801
# Converting text 5901
# Converting text 6001
# Converting text 6101
# Converting text 6201
# Converting text 6301
# Converting text 6401
# Converting text 6501
# Converting text 6601
# Converting text 6701
# Converting text 6801
# Converting text 6901
# Converting text 7001
# Converting text 7101
# Converting text 7201
# Converting text 7301
# Converting text 7401
# Converting text 7501
# Converting text 7601
# Converting text 7701
# Converting text 7801
# Converting text 7901
# Converting text 8001
# Converting text 8101
# Converting text 8201
# Converting text 8301
# Converting text 8401
# Converting text 8501
# Converting text 8601
# Converting text 8701
# Converting text 8801
# Converting text 8901
# Converting text 9001
# Converting text 9101
# Converting text 9201
# Converting text 9301
# Converting text 9401
# Converting text 9501
# Converting text 9601
# Converting text 9701
# Converting text 9801
# Converting text 9901
# Converting text 10001
# Converting text 10101
# Converting text 10201
# Converting text 10301
# Converting text 10401
# Converting text 10501
# Converting text 10601
# Converting text 10701
# Converting text 10801
# Converting text 10901
# Converting text 11001
# Converting text 11101
# Converting text 11201
# Converting text 11301
# Converting text 11401
# Converting text 11501
# Converting text 11601
# Converting text 11701
# Converting text 11801
# Converting text 11901
# Converting text 12001
# Converting text 12101
# Converting text 12201
# Converting text 12301
# Converting text 12401
# Converting text 12501
# Converting text 12601
# Converting text 12701
# Converting text 12801
# Converting text 12901
# Converting text 13001
# Converting text 13101
# Converting text 13201
# Converting text 13301
# Converting text 13401
# Converting text 13501
# Converting text 13601
# Converting text 13701
# Converting text 13801
# Converting text 13901
# Converting text 14001
# Converting text 14101
# Converting text 14201
# Converting text 14301
# Converting text 14401
# Converting text 14501
# Converting text 14601
# Converting text 14701
# Converting text 14801
# Converting text 14901
# Converting text 15001
# Converting text 15101
# Converting text 15201
# Converting text 15301
# Converting text 15401
# Converting text 15501
# Converting text 15601
# Converting text 15701
# Converting text 15801
# Converting text 15901
# Converting text 16001
# Converting text 16101
# Converting text 16201
# Converting text 16301
# Converting text 16401
# Converting text 16501
# Converting text 16601
# Converting text 16701
# Converting text 16801
# Converting text 16901
# Converting text 17001
# Converting text 17101
# Converting text 17201
# Converting text 17301
# Converting text 17401
# Converting text 17501
# Converting text 17601
# Converting text 17701
# Converting text 17801
# Converting text 17901
# Converting text 18001
# Converting text 18101
# Converting text 18201
# Converting text 18301
# Converting text 18401
# Converting text 18501
# Converting text 18601
# Converting text 18701
# Converting text 18801
# Converting text 18901
# Converting text 19001
# Converting text 19101
# Converting text 19201
# Converting text 19301
# Converting text 19401
# Converting text 19501
# Converting text 19601
# Converting text 19701
# Converting text 19801
# Converting text 19901
# Converting text 20001
# Converting text 20101
# Converting text 20201
# Converting text 20301
# Converting text 20401
# Converting text 20501
# Converting text 20601
# Converting text 20701
# Converting text 20801
# Converting text 20901
# Converting text 21001
# Converting text 21101
# Converting text 21201
# Converting text 21301
# Converting text 21401
# Converting text 21501
# Converting text 21601
# Converting text 21701
# Converting text 21801
# Converting text 21901
# Converting text 22001
# Converting text 22101
# Converting text 22201
# Converting text 22301
# Converting text 22401
# Converting text 22501
# Converting text 22601
# Converting text 22701
# Converting text 22801
# Converting text 22901
# Converting text 23001
# Converting text 23101
# Converting text 23201
# Converting text 23301
# Converting text 23401
# Converting text 23501
# Converting text 23601
# Converting text 23701
# Converting text 23801
# Converting text 23901
# Converting text 24001
# Converting text 24101
# Converting text 24201
# Converting text 24301
# Converting text 24401
# Converting text 24501
# Converting text 24601
# Converting text 24701
# Converting text 24801
# Converting text 24901
# Converting text 25001
# Converting text 25101
# Converting text 25201
# Converting text 25301
# Converting text 25401
# Converting text 25501
# Converting text 25601
# Converting text 25701
# Converting text 25801
# Converting text 25901
# Converting text 26001
# Converting text 26101
# Converting text 26201
# Converting text 26301
# Converting text 26401
# Converting text 26501
# Converting text 26601
# Converting text 26701
# Converting text 26801
# Converting text 26901
# Converting text 27001
# Converting text 27101
# Converting text 27201
# Converting text 27301
# Converting text 27401
# Converting text 27501
# Converting text 27601
# Converting text 27701
# Converting text 27801
# Converting text 27901
# Converting text 28001
# Converting text 28101
# Converting text 28201
# Converting text 28301
# Converting text 28401
# Converting text 28501
# Converting text 28601
# Converting text 28701
# Converting text 28801
# Converting text 28901
# Converting text 29001
# Converting text 29101
# Converting text 29201
# Converting text 29301
# Converting text 29401
# Converting text 29501
# Converting text 29601
# Converting text 29701
# Converting text 29801
# Converting text 29901
# Converting text 30001
# Converting text 30101
# Converting text 30201
# Converting text 30301
# Converting text 30401
# Converting text 30501
# Converting text 30601
# Converting text 30701
# Converting text 30801
# Converting text 30901
# Converting text 31001
# Converting text 31101
# Converting text 31201
# Converting text 31301
# Converting text 31401
# Converting text 31501
# Converting text 31601
# Converting text 31701
# Converting text 31801
# Converting text 31901
# Converting text 32001
# Converting text 32101
# Converting text 32201
# Converting text 32301
# Converting text 32401
# Converting text 32501
# Converting text 32601
# Converting text 32701
# Converting text 32801
# Converting text 32901
# Converting text 33001
# Converting text 33101
# Converting text 33201
# Converting text 33301
# Converting text 33401
# Converting text 33501
# Converting text 33601
# Converting text 33701
# Converting text 33801
# Converting text 33901
# Converting text 34001
# Converting text 34101
# Converting text 34201
# Converting text 34301
# Converting text 34401
# Converting text 34501
# Converting text 34601
# Converting text 34701
# Converting text 34801
# Converting text 34901
# Converting text 35001
# Converting text 35101
# Converting text 35201
# Converting text 35301
# Converting text 35401
# Converting text 35501
# Converting text 35601
# Converting text 35701
# Converting text 35801
# Converting text 35901
# Converting text 36001
# Converting text 36101
# Converting text 36201
# Converting text 36301
# Converting text 36401
# Converting text 36501
# Converting text 36601
# Converting text 36701
# Converting text 36801
# Converting text 36901
# Converting text 37001
# Converting text 37101
# Converting text 37201
# Converting text 37301
# Converting text 37401
# Converting text 37501
# Converting text 37601
# Converting text 37701
# Converting text 37801
# Converting text 37901
# Converting text 38001
# Converting text 38101
# Converting text 38201
# Converting text 38301
# Converting text 38401
# Converting text 38501
# Converting text 38601
# Converting text 38701
# Converting text 38801
# Converting text 38901
# Converting text 39001
# Converting text 39101
# Converting text 39201
# Converting text 39301
# Converting text 39401
# Converting text 39501
# Converting text 39601
# Converting text 39701
# Converting text 39801
# Converting text 39901
# Converting text 40001
# Converting text 40101
# Converting text 40201
# Converting text 40301
# Converting text 40401
# Converting text 40501
# Converting text 40601
# Converting text 40701
# Converting text 40801
# Converting text 40901
# Converting text 41001
# Converting text 41101
# Converting text 41201
# Converting text 41301
# Converting text 41401
# Converting text 41501
# Converting text 41601
# Converting text 41701
# Converting text 41801
# Converting text 41901
# Converting text 42001
# Converting text 42101
# Converting text 42201
# Converting text 42301
# Converting text 42401
# Converting text 42501
# Converting text 42601
# Converting text 42701
# Converting text 42801
# Converting text 42901
# Converting text 43001
# Converting text 43101
# Converting text 43201
# Converting text 43301
# Converting text 43401
# Converting text 43501
# Converting text 43601
# Converting text 43701
# Converting text 43801
# Converting text 43901
# Converting text 44001
# Converting text 44101
# Converting text 44201
# Converting text 44301
# Converting text 44401
# Converting text 44501
# Converting text 44601
# Converting text 44701
# Converting text 44801
# Converting text 44901
# Converting text 45001
# Converting text 45101
# Converting text 45201
# Converting text 45301
# Converting text 45401
# Converting text 45501
# Converting text 45601
# Converting text 45701
# Converting text 45801
# Converting text 45901
# Converting text 46001
# Converting text 46101
# Converting text 46201
# Converting text 46301
# Converting text 46401
# Converting text 46501
# Converting text 46601
# Converting text 46701
# Converting text 46801
# Converting text 46901
# Converting text 47001
# Converting text 47101
# Converting text 47201
# Converting text 47301
# Converting text 47401
# Converting text 47501
# Converting text 47601
# Converting text 47701
# Converting text 47801
# Converting text 47901
# Converting text 48001
# Converting text 48101
# Converting text 48201
# Converting text 48301
# Converting text 48401
# Converting text 48501
# Converting text 48601
# Converting text 48701
# Converting text 48801
# Converting text 48901
# Converting text 49001
# Converting text 49101
# Converting text 49201
# Converting text 49301
# Converting text 49401
# Converting text 49501
# Converting text 49601
# Converting text 49701
# Converting text 49801
# Converting text 49901
# Converting text 50001
# Converting text 50101
# Converting text 50201
# Converting text 50301
# Converting text 50401
# Converting text 50501
# Converting text 50601
# Converting text 50701
# Converting text 50801
# Converting text 50901
# Converting text 51001
# Converting text 51101
# Converting text 51201
# Converting text 51301
# Converting text 51401
# Converting text 51501
# Converting text 51601
# Converting text 51701
# Converting text 51801
# Converting text 51901
# Converting text 52001
# Converting text 52101
# Converting text 52201
# Converting text 52301
# Converting text 52401
# Converting text 52501
# Converting text 52601
# Converting text 52701
# Converting text 52801
# Converting text 52901
# Converting text 53001
# Converting text 53101
# Converting text 53201
# Converting text 53301
# Converting text 53401
# Converting text 53501
# Converting text 53601
# Converting text 53701
# Converting text 53801
# Converting text 53901
# Converting text 54001
# Converting text 54101
# Converting text 54201
# Converting text 54301
# Converting text 54401
# Converting text 54501
# Converting text 54601
# Converting text 54701
# Converting text 54801
# Converting text 54901
# Converting text 55001
# Converting text 55101
# Converting text 55201
# Converting text 55301
# Converting text 55401
# Converting text 55501
# Converting text 55601
# Converting text 55701
# Converting text 55801
# Converting text 55901
# Converting text 56001
# Converting text 56101
# Converting text 56201
# Converting text 56301
# Converting text 56401
# Converting text 56501
# Converting text 56601
# Converting text 56701
# Converting text 56801
# Converting text 56901
# Converting text 57001
# Converting text 57101
# Converting text 57201
# Converting text 57301
# Converting text 57401
# Converting text 57501
# Converting text 57601
# Converting text 57701
# Converting text 57801
# Converting text 57901
# Converting text 58001
# Converting text 58101
# Converting text 58201
# Converting text 58301
# Converting text 58401
# Converting text 58501
# Converting text 58601
# Converting text 58701
# Converting text 58801
# Converting text 58901
# Converting text 59001
# Converting text 59101
# Converting text 59201
# Converting text 59301
# Converting text 59401
# Converting text 59501
# Converting text 59601
# Converting text 59701
# Converting text 59801
# Converting text 59901
# Converting text 60001
# Converting text 60101
# Converting text 60201
# Converting text 60301
# Converting text 60401
# Converting text 60501
# Converting text 60601
# Converting text 60701
# Converting text 60801
# Converting text 60901
# Converting text 61001
# Converting text 61101
# Converting text 61201
# Converting text 61301
# Converting text 61401
# Converting text 61501
# Converting text 61601
# Converting text 61701
# Converting text 61801
# Converting text 61901
# Converting text 62001
# Converting text 62101
# Converting text 62201
# Converting text 62301
# Converting text 62401
# Converting text 62501
# Converting text 62601
# Converting text 62701
# Converting text 62801
# Converting text 62901
# Converting text 63001
# Converting text 63101
# Converting text 63201
# Converting text 63301
# Converting text 63401
# Converting text 63501
# Converting text 63601
# Converting text 63701
# Converting text 63801
# Converting text 63901
# Converting text 64001
# Converting text 64101
# Converting text 64201
# Converting text 64301
# Converting text 64401
# Converting text 64501
# Converting text 64601
# Converting text 64701
# Converting text 64801
# Converting text 64901
# Converting text 65001
# Converting text 65101
# Converting text 65201
# Converting text 65301
# Converting text 65401
# Converting text 65501
# Converting text 65601
# Converting text 65701
# Converting text 65801
# Converting text 65901
# Converting text 66001
# Converting text 66101
# Converting text 66201
# Converting text 66301
# Converting text 66401
# Converting text 66501
# Converting text 66601
# Converting text 66701
# Converting text 66801
# Converting text 66901
# Converting text 67001
# Converting text 67101
# Converting text 67201
# Converting text 67301
# Converting text 67401
# Converting text 67501
# Converting text 67601
# Converting text 67701
# Converting text 67801
# Converting text 67901
# Converting text 68001
# Converting text 68101
# Converting text 68201
# Converting text 68301
# Converting text 68401
# Converting text 68501
# Converting text 68601
# Converting text 68701
# Converting text 68801
# Converting text 68901
# Converting text 69001
# Converting text 69101
# Converting text 69201
# Converting text 69301
# Converting text 69401
# Converting text 69501
# Converting text 69601
# Converting text 69701
# Converting text 69801
# Converting text 69901
# Converting text 70001
# Converting text 70101
# Converting text 70201
# Converting text 70301
# Converting text 70401
# Converting text 70501
# Converting text 70601
# Converting text 70701
# Converting text 70801
# Converting text 70901
# Converting text 71001
# Converting text 71101
# Converting text 71201
# Converting text 71301
# Converting text 71401
# Converting text 71501
# Converting text 71601
# Converting text 71701
# Converting text 71801
# Converting text 71901
# Converting text 72001
# Converting text 72101
# Converting text 72201
# Converting text 72301
# Converting text 72401
# Converting text 72501
# Converting text 72601
# Converting text 72701
# Converting text 72801
# Converting text 72901
# Converting text 73001
# Converting text 73101
# Converting text 73201
# Converting text 73301
# Converting text 73401
# Converting text 73501
# Converting text 73601
# Converting text 73701
# Converting text 73801
# Converting text 73901
# Converting text 74001
# Converting text 74101
# Converting text 74201
# Converting text 74301
# Converting text 74401
# Converting text 74501
# Converting text 74601
# Converting text 74701
# Converting text 74801
# Converting text 74901
# Converting text 75001
# Converting text 75101
# Converting text 75201
# Converting text 75301
# Converting text 75401
# Converting text 75501
# Converting text 75601
# Converting text 75701
# Converting text 75801
# Converting text 75901
# Converting text 76001
# Converting text 76101
# Converting text 76201
# Converting text 76301
# Converting text 76401
# Converting text 76501
# Converting text 76601
# Converting text 76701
# Converting text 76801
# Converting text 76901
# Converting text 77001
# Converting text 77101
# Converting text 77201
# Converting text 77301
# Converting text 77401
# Converting text 77501
# Converting text 77601
# Converting text 77701
# Converting text 77801
# Converting text 77901
# Converting text 78001
# Converting text 78101
# Converting text 78201
# Converting text 78301
# Converting text 78401
# Converting text 78501
# Converting text 78601
# Converting text 78701
# Converting text 78801
# Converting text 78901
# Converting text 79001
# Converting text 79101
# Converting text 79201
# Converting text 79301
# Converting text 79401
# Converting text 79501
# Converting text 79601
# Converting text 79701
# Converting text 79801
# Converting text 79901
# Converting text 80001
# Converting text 80101
# Converting text 80201
# Converting text 80301
# Converting text 80401
# Converting text 80501
# Converting text 80601
# Converting text 80701
# Converting text 80801
# Converting text 80901
# Converting text 81001
# Converting text 81101
# Converting text 81201
# Converting text 81301
# Converting text 81401
# Converting text 81501
# Converting text 81601
# Converting text 81701
# Converting text 81801
# Converting text 81901
# Converting text 82001
# Converting text 82101
# Converting text 82201
# Converting text 82301
# Converting text 82401
# Converting text 82501
# Converting text 82601
# Converting text 82701
# Converting text 82801
# Converting text 82901
# Converting text 83001
# Converting text 83101
# Converting text 83201
# Converting text 83301
# Converting text 83401
# Converting text 83501
# Converting text 83601
# Converting text 83701
# Converting text 83801
# Converting text 83901
# Converting text 84001
# Converting text 84101
# Converting text 84201
# Converting text 84301
# Converting text 84401
# Converting text 84501
# Converting text 84601
# Converting text 84701
# Converting text 84801
# Converting text 84901
# Converting text 85001
# Converting text 85101
# Converting text 85201
# Converting text 85301
# Converting text 85401
# Converting text 85501
# Converting text 85601
# Converting text 85701
# Converting text 85801
# Converting text 85901
# Converting text 86001
# Converting text 86101
# Converting text 86201
# Converting text 86301
# Converting text 86401
# Converting text 86501
# Converting text 86601
# Converting text 86701
# Converting text 86801
# Converting text 86901
# Converting text 87001
# Converting text 87101
# Converting text 87201
# Converting text 87301
# Converting text 87401
# Converting text 87501
# Converting text 87601
# Converting text 87701
# Converting text 87801
# Converting text 87901
# Converting text 88001
# Converting text 88101
# Converting text 88201
# Converting text 88301
# Converting text 88401
# Converting text 88501
# Converting text 88601
# Converting text 88701
# Converting text 88801
# Converting text 88901
# Converting text 89001
# Converting text 89101
# Converting text 89201
# Converting text 89301
# Converting text 89401
# Converting text 89501
# Converting text 89601
# Converting text 89701
# Converting text 89801
# Converting text 89901
# Converting text 90001
# Converting text 90101
# Converting text 90201
# Converting text 90301
# Converting text 90401
# Converting text 90501
# Converting text 90601
# Converting text 90701
# Converting text 90801
# Converting text 90901
# Converting text 91001
# Converting text 91101
# Converting text 91201
# Converting text 91301
# Converting text 91401
# Converting text 91501
# Converting text 91601
# Converting text 91701
# Converting text 91801
# Converting text 91901
# Converting text 92001
# Converting text 92101
# Converting text 92201
# Converting text 92301
# Converting text 92401
# Converting text 92501
# Converting text 92601
# Converting text 92701
# Converting text 92801
# Converting text 92901
# Converting text 93001
# Converting text 93101
# Converting text 93201
# Converting text 93301
# Converting text 93401
# Converting text 93501
# Converting text 93601
# Converting text 93701
# Converting text 93801
# Converting text 93901
# Converting text 94001
# Converting text 94101
# Converting text 94201
# Converting text 94301
# Converting text 94401
# Converting text 94501
# Converting text 94601
# Converting text 94701
# Converting text 94801
# Converting text 94901
# Converting text 95001
# Converting text 95101
# Converting text 95201
# Converting text 95301
# Converting text 95401
# Converting text 95501
# Converting text 95601
# Converting text 95701
# Converting text 95801
# Converting text 95901
# Converting text 96001
# Converting text 96101
# Converting text 96201
# Converting text 96301
# Converting text 96401
# Converting text 96501
# Converting text 96601
# Converting text 96701
# Converting text 96801
# Converting text 96901
# Converting text 97001
# Converting text 97101
# Converting text 97201
# Converting text 97301
# Converting text 97401
# Converting text 97501
# Converting text 97601
# Converting text 97701
# Converting text 97801
# Converting text 97901
# Converting text 98001
# Converting text 98101
# Converting text 98201
# Converting text 98301
# Converting text 98401
# Converting text 98501
# Converting text 98601
# Converting text 98701
# Converting text 98801
# Converting text 98901
# Converting text 99001
# Converting text 99101
# Converting text 99201
# Converting text 99301
# Converting text 99401
# Converting text 99501
# Converting text 99601
# Converting text 99701
# Converting text 99801
# Converting text 99901
# Converting text 100001
# Converting text 100101
# Converting text 100201
# Converting text 100301
# Converting text 100401
# Converting text 100501
# Converting text 100601
# Converting text 100701
# Converting text 100801
# Converting text 100901
# Converting text 101001
# Converting text 101101
# Converting text 101201
# Converting text 101301
# Converting text 101401
# Converting text 101501
# Converting text 101601
# Converting text 101701
# Converting text 101801
# Converting text 101901
# Converting text 102001
# Converting text 102101
# Converting text 102201
# Converting text 102301
# Converting text 102401
# Converting text 102501
# Converting text 102601
# Converting text 102701
# Converting text 102801
# Converting text 102901
# Converting text 103001
# Converting text 103101
# Converting text 103201
# Converting text 103301
# Converting text 103401
# Converting text 103501
# Converting text 103601
# Converting text 103701
# Converting text 103801
# Converting text 103901
# Converting text 104001
# Converting text 104101
# Converting text 104201
# Converting text 104301
# Converting text 104401
# Converting text 104501
# Converting text 104601
# Converting text 104701
# Converting text 104801
# Converting text 104901
# Converting text 105001
# Converting text 105101
# Converting text 105201
# Converting text 105301
# Converting text 105401
# Converting text 105501
# Converting text 105601
# Converting text 105701
# Converting text 105801
# Converting text 105901
# Converting text 106001
# Converting text 106101
# Converting text 106201
# Converting text 106301
# Converting text 106401
# Converting text 106501
# Converting text 106601
# Converting text 106701
# Converting text 106801
# Converting text 106901
# Converting text 107001
# Converting text 107101
# Converting text 107201
# Converting text 107301
# Converting text 107401
# Converting text 107501
# Converting text 107601
# Converting text 107701
# Converting text 107801
# Converting text 107901
# Converting text 108001
# Converting text 108101
# Converting text 108201
# Converting text 108301
# Converting text 108401
# Converting text 108501
# Converting text 108601
# Converting text 108701
# Converting text 108801
# Converting text 108901
# Converting text 109001
# Converting text 109101
# Converting text 109201
# Converting text 109301
# Converting text 109401
# Converting text 109501
# Converting text 109601
# Converting text 109701
# Converting text 109801
# Converting text 109901
# Converting text 110001
# Converting text 110101
# Converting text 110201
# Converting text 110301
# Converting text 110401
# Converting text 110501
# Converting text 110601
# Converting text 110701
# Converting text 110801
# Converting text 110901
# Converting text 111001
# Converting text 111101
# Converting text 111201
# Converting text 111301
# Converting text 111401
# Converting text 111501
# Converting text 111601
# Converting text 111701
# Converting text 111801
# Converting text 111901
# Converting text 112001
# Converting text 112101
# Converting text 112201
# Converting text 112301
# Converting text 112401
# Converting text 112501
# Converting text 112601
# Converting text 112701
# Converting text 112801
# Converting text 112901
# Converting text 113001
# Converting text 113101
# Converting text 113201
# Converting text 113301
# Converting text 113401
# Converting text 113501
# Converting text 113601
# Converting text 113701
# Converting text 113801
# Converting text 113901
# Converting text 114001
# Converting text 114101
# Converting text 114201
# Converting text 114301
# Converting text 114401
# Converting text 114501
# Converting text 114601
# Converting text 114701
# Converting text 114801
# Converting text 114901
# Converting text 115001
# Converting text 115101
# Converting text 115201
# Converting text 115301
# Converting text 115401
# Converting text 115501
# Converting text 115601
# Converting text 115701
# Converting text 115801
# Converting text 115901
# Converting text 116001
# Converting text 116101
# Converting text 116201
# Converting text 116301
# Converting text 116401
# Converting text 116501
# Converting text 116601
# Converting text 116701
# Converting text 116801
# Converting text 116901
# Converting text 117001
# Converting text 117101
# Converting text 117201
# Converting text 117301
# Converting text 117401
# Converting text 117501
# Converting text 117601
# Converting text 117701
# Converting text 117801
# Converting text 117901
# Converting text 118001
# Converting text 118101
# Converting text 118201
# Converting text 118301
# Converting text 118401
# Converting text 118501
# Converting text 118601
# Converting text 118701
# Converting text 118801
# Converting text 118901
# Converting text 119001
# Converting text 119101
# Converting text 119201
# Converting text 119301
# Converting text 119401
# Converting text 119501
# Converting text 119601
# Converting text 119701
# Converting text 119801
# Converting text 119901
# Converting text 120001
# Converting text 120101
# Converting text 120201
# Converting text 120301
# Converting text 120401
# Converting text 120501
# Converting text 120601
# Converting text 120701
# Converting text 120801
# Converting text 120901
# Converting text 121001
# Converting text 121101
# Converting text 121201
# Converting text 121301
# Converting text 121401
# Converting text 121501
# Converting text 121601
# Converting text 121701
# Converting text 121801
# Converting text 121901
# Converting text 122001
# Converting text 122101
# Converting text 122201
# Converting text 122301
# Converting text 122401
# Converting text 122501
# Converting text 122601
# Converting text 122701
# Converting text 122801
# Converting text 122901
# Converting text 123001
# Converting text 123101
# Converting text 123201
# Converting text 123301
# Converting text 123401
# Converting text 123501
# Converting text 123601
# Converting text 123701
# Converting text 123801
# Converting text 123901
# Converting text 124001
# Converting text 124101
# Converting text 124201
# Converting text 124301
# Converting text 124401
# Converting text 124501
# Converting text 124601
# Converting text 124701
# Converting text 124801
# Converting text 124901
# Converting text 125001
# Converting text 125101
# Converting text 125201
# Converting text 125301
# Converting text 125401
# Converting text 125501
# Converting text 125601
# Converting text 125701
# Converting text 125801
# Converting text 125901
# Converting text 126001
# Converting text 126101
# Converting text 126201
# Converting text 126301
# Converting text 126401
# Converting text 126501
# Converting text 126601
# Converting text 126701
# Converting text 126801
# Converting text 126901
# Converting text 127001
# Converting text 127101
# Converting text 127201
# Converting text 127301
# Converting text 127401
# Converting text 127501
# Converting text 127601
# Converting text 127701
# Converting text 127801
# Converting text 127901
# Converting text 128001
# Converting text 128101
# Converting text 128201
# Converting text 128301
# Converting text 128401
# Converting text 128501
# Converting text 128601
# Converting text 128701
# Converting text 128801
# Converting text 128901
# Converting text 129001
# Converting text 129101
# Converting text 129201
# Converting text 129301
# Converting text 129401
# Converting text 129501
# Converting text 129601
# Converting text 129701
# Converting text 129801
# Converting text 129901
# Converting text 130001
# Converting text 130101
# Converting text 130201
# Converting text 130301
# Converting text 130401
# Converting text 130501
# Converting text 130601
# Converting text 130701
# Converting text 130801
# Converting text 130901
# Converting text 131001
# Converting text 131101
# Converting text 131201
# Converting text 131301
# Converting text 131401
# Converting text 131501
# Converting text 131601
# Converting text 131701
# Converting text 131801
# Converting text 131901
# Converting text 132001
# Converting text 132101
# Converting text 132201
# Converting text 132301
# Converting text 132401
# Converting text 132501
# Converting text 132601
# Converting text 132701
# Converting text 132801
# Converting text 132901
# Converting text 133001
# Converting text 133101
# Converting text 133201
# Converting text 133301
# Converting text 133401
# Converting text 133501
# Converting text 133601
# Converting text 133701
# Converting text 133801
# Converting text 133901
# Converting text 134001
# Converting text 134101
# Converting text 134201
# Converting text 134301
# Converting text 134401
# Converting text 134501
# Converting text 134601
# Converting text 134701
# Converting text 134801
# Converting text 134901
# Converting text 135001
# Converting text 135101
# Converting text 135201
# Converting text 135301
# Converting text 135401
# Converting text 135501
# Converting text 135601
# Converting text 135701
# Converting text 135801
# Converting text 135901
# Converting text 136001
# Converting text 136101
# Converting text 136201
# Converting text 136301
# Converting text 136401
# Converting text 136501
# Converting text 136601
# Converting text 136701
# Converting text 136801
# Converting text 136901
# Converting text 137001
# Converting text 137101
# Converting text 137201
# Converting text 137301
# Converting text 137401
# Converting text 137501
# Converting text 137601
# Converting text 137701
# Converting text 137801
# Converting text 137901
# Converting text 138001
# Converting text 138101
# Converting text 138201
# Converting text 138301
# Converting text 138401
# Converting text 138501
# Converting text 138601
# Converting text 138701
# Converting text 138801
# Converting text 138901
# Converting text 139001
# Converting text 139101
# Converting text 139201
# Converting text 139301
# Converting text 139401
# Converting text 139501
# Converting text 139601
# Converting text 139701
# Converting text 139801
# Converting text 139901
# Converting text 140001
# Converting text 140101
# Converting text 140201
# Converting text 140301
# Converting text 140401
# Converting text 140501
# Converting text 140601
# Converting text 140701
# Converting text 140801
# Converting text 140901
# Converting text 141001
# Converting text 141101
# Converting text 141201
# Converting text 141301
# Converting text 141401
# Converting text 141501
# Converting text 141601
# Converting text 141701
# Converting text 141801
# Converting text 141901
# Converting text 142001
# Converting text 142101
# Converting text 142201
# Converting text 142301
# Converting text 142401
# Converting text 142501
# Converting text 142601
# Converting text 142701
# Converting text 142801
# Converting text 142901
# Converting text 143001
# Converting text 143101
# Converting text 143201
# Converting text 143301
# Converting text 143401
# Converting text 143501
# Converting text 143601
# Converting text 143701
# Converting text 143801
# Converting text 143901
# Converting text 144001
# Converting text 144101
# Converting text 144201
# Converting text 144301
# Converting text 144401
# Converting text 144501
# Converting text 144601
# Converting text 144701
# Converting text 144801
# Converting text 144901
# Converting text 145001
# Converting text 145101
# Converting text 145201
# Converting text 145301
# Converting text 145401
# Converting text 145501
# Converting text 145601
# Converting text 145701
# Converting text 145801
# Converting text 145901
# Converting text 146001
# Converting text 146101
# Converting text 146201
# Converting text 146301
# Converting text 146401
# Converting text 146501
# Converting text 146601
# Converting text 146701
# Converting text 146801
# Converting text 146901
# Converting text 147001
# Converting text 147101
# Converting text 147201
# Converting text 147301
# Converting text 147401
# Converting text 147501
# Converting text 147601
# Converting text 147701
# Converting text 147801
# Converting text 147901
# Converting text 148001
# Converting text 148101
# Converting text 148201
# Converting text 148301
# Converting text 148401
# Converting text 148501
# Converting text 148601
# Converting text 148701
# Converting text 148801
# Converting text 148901
# Converting text 149001
# Converting text 149101
# Converting text 149201
# Converting text 149301
# Converting text 149401
# Converting text 149501
# Converting text 149601
# Converting text 149701
# Converting text 149801
# Converting text 149901
# Converting text 150001
# Converting text 150101
# Converting text 150201
# Converting text 150301
# Converting text 150401
# Converting text 150501
# Converting text 150601
# Converting text 150701
# Converting text 150801
# Converting text 150901
# Converting text 151001
# Converting text 151101
# Converting text 151201
# Converting text 151301
# Converting text 151401
# Converting text 151501
# Converting text 151601
# Converting text 151701
# Converting text 151801
# Converting text 151901
# Converting text 152001
# Converting text 152101
# Converting text 152201
# Converting text 152301
# Converting text 152401
# Converting text 152501
# Converting text 152601
# Converting text 152701
# Converting text 152801
# Converting text 152901
# Converting text 153001
# Converting text 153101
# Converting text 153201
# Converting text 153301
# Converting text 153401
# Converting text 153501
# Converting text 153601
# Converting text 153701
# Converting text 153801
# Converting text 153901
# Converting text 154001
# Converting text 154101
# Converting text 154201
# Converting text 154301
# Converting text 154401
# Converting text 154501
# Converting text 154601
# Converting text 154701
# Converting text 154801
# Converting text 154901
# Converting text 155001
# Converting text 155101
# Converting text 155201
# Converting text 155301
# Converting text 155401
# Converting text 155501
# Converting text 155601
# Converting text 155701
# Converting text 155801
# Converting text 155901
# Converting text 156001
# Converting text 156101
# Converting text 156201
# Converting text 156301
# Converting text 156401
# Converting text 156501
# Converting text 156601
# Converting text 156701
# Converting text 156801
# Converting text 156901
# Converting text 157001
# Converting text 157101
# Converting text 157201
# Converting text 157301
# Converting text 157401
# Converting text 157501
# Converting text 157601
# Converting text 157701
# Converting text 157801
# Converting text 157901
# Converting text 158001
# Converting text 158101
# Converting text 158201
# Converting text 158301
# Converting text 158401
# Converting text 158501
# Converting text 158601
# Converting text 158701
# Converting text 158801
# Converting text 158901
# Converting text 159001
# Converting text 159101
# Converting text 159201
# Converting text 159301
# Converting text 159401
# Converting text 159501
# Converting text 159601
# Converting text 159701
# Converting text 159801
# Converting text 159901
# Converting text 160001
# Converting text 160101
# Converting text 160201
# Converting text 160301
# Converting text 160401
# Converting text 160501
# Converting text 160601
# Converting text 160701
# Converting text 160801
# Converting text 160901
# Converting text 161001
# Converting text 161101
# Converting text 161201
# Converting text 161301
# Converting text 161401
# Converting text 161501
# Converting text 161601
# Converting text 161701
# Converting text 161801
# Converting text 161901
# Converting text 162001
# Converting text 162101
# Converting text 162201
# Converting text 162301
# Converting text 162401
# Converting text 162501
# Converting text 162601
# Converting text 162701
# Converting text 162801
# Converting text 162901
# Converting text 163001
# Converting text 163101
# Converting text 163201
# Converting text 163301
# Converting text 163401
# Converting text 163501
# Converting text 163601
# Converting text 163701
# Converting text 163801
# Converting text 163901
# Converting text 164001
# Converting text 164101
# Converting text 164201
# Converting text 164301
# Converting text 164401
# Converting text 164501
# Converting text 164601
# Converting text 164701
# Converting text 164801
# Converting text 164901
# Converting text 165001
# Converting text 165101
# Converting text 165201
# Converting text 165301
# Converting text 165401
# Converting text 165501
# Converting text 165601
# Converting text 165701
# Converting text 165801
# Converting text 165901
# Converting text 166001
# Converting text 166101
# Converting text 166201
# Converting text 166301
# Converting text 166401
# Converting text 166501
# Converting text 166601
# Converting text 166701
# Converting text 166801
# Converting text 166901
# Converting text 167001
# Converting text 167101
# Converting text 167201
# Converting text 167301
# Converting text 167401
# Converting text 167501
# Converting text 167601
# Converting text 167701
# Converting text 167801
# Converting text 167901
# Converting text 168001
# Converting text 168101
# Converting text 168201
# Converting text 168301
# Converting text 168401
# Converting text 168501
# Converting text 168601
# Converting text 168701
# Converting text 168801
# Converting text 168901
# Converting text 169001
# Converting text 169101
# Converting text 169201
# Converting text 169301
# Converting text 169401
# Converting text 169501
# Converting text 169601
# Converting text 169701
# Converting text 169801
# Converting text 169901
# Converting text 170001
# Converting text 170101
# Converting text 170201
# Converting text 170301
# Converting text 170401
# Converting text 170501
# Converting text 170601
# Converting text 170701
# Converting text 170801
# Converting text 170901
# Converting text 171001
# Converting text 171101
# Converting text 171201
# Converting text 171301
# Converting text 171401
# Converting text 171501
# Converting text 171601
# Converting text 171701
# Converting text 171801
# Converting text 171901
# Converting text 172001
# Converting text 172101
# Converting text 172201
# Converting text 172301
# Converting text 172401
# Converting text 172501
# Converting text 172601
# Converting text 172701
# Converting text 172801
# Converting text 172901
# Converting text 173001
# Converting text 173101
# Converting text 173201
# Converting text 173301
# Converting text 173401
# Converting text 173501
# Converting text 173601
# Converting text 173701
# Converting text 173801
# Converting text 173901
# Converting text 174001
# Converting text 174101
# Converting text 174201
# Converting text 174301
# Converting text 174401
# Converting text 174501
# Converting text 174601
# Converting text 174701
# Converting text 174801
# Converting text 174901
# Converting text 175001
# Converting text 175101
# Converting text 175201
# Converting text 175301
# Converting text 175401
# Converting text 175501
# Converting text 175601
# Converting text 175701
# Converting text 175801
# Converting text 175901
# Converting text 176001
# Converting text 176101
# Converting text 176201
# Converting text 176301
# Converting text 176401
# Converting text 176501
# Converting text 176601
# Converting text 176701
# Converting text 176801
# Converting text 176901
# Converting text 177001
# Converting text 177101
# Converting text 177201
# Converting text 177301
# Converting text 177401
# Converting text 177501
# Converting text 177601
# Converting text 177701
# Converting text 177801
# Converting text 177901
# Converting text 178001
# Converting text 178101
# Converting text 178201
# Converting text 178301
# Converting text 178401
# Converting text 178501
# Converting text 178601
# Converting text 178701
# Converting text 178801
# Converting text 178901
# Converting text 179001
# Converting text 179101
# Converting text 179201
# Converting text 179301
# Converting text 179401
# Converting text 179501
# Converting text 179601
# Converting text 179701
# Converting text 179801
# Converting text 179901
# Converting text 180001
# Converting text 180101
# Converting text 180201
# Converting text 180301
# Converting text 180401
# Converting text 180501
# Converting text 180601
# Converting text 180701
# Converting text 180801
# Converting text 180901
# Converting text 181001
# Converting text 181101
# Converting text 181201
# Converting text 181301
# Converting text 181401
# Converting text 181501
# Converting text 181601
# Converting text 181701
# Converting text 181801
# Converting text 181901
# Converting text 182001
# Converting text 182101
# Converting text 182201
# Converting text 182301
# Converting text 182401
# Converting text 182501
# Converting text 182601
# Converting text 182701
# Converting text 182801
# Converting text 182901
# Converting text 183001
# Converting text 183101
# Converting text 183201
# Converting text 183301
# Converting text 183401
# Converting text 183501
# Converting text 183601
# Converting text 183701
# Converting text 183801
# Converting text 183901
# Converting text 184001
# Converting text 184101
# Converting text 184201
# Converting text 184301
# Converting text 184401
# Converting text 184501
# Converting text 184601
# Converting text 184701
# Converting text 184801
# Converting text 184901
# Converting text 185001
# Converting text 185101
# Converting text 185201
# Converting text 185301
# Converting text 185401
# Converting text 185501
# Converting text 185601
# Converting text 185701
# Converting text 185801
# Converting text 185901
# Converting text 186001
# Converting text 186101
# Converting text 186201
# Converting text 186301
# Converting text 186401
# Converting text 186501
# Converting text 186601
# Converting text 186701
# Converting text 186801
# Converting text 186901
# Converting text 187001
# Converting text 187101
# Converting text 187201
# Converting text 187301
# Converting text 187401
# Converting text 187501
# Converting text 187601
# Converting text 187701
# Converting text 187801
# Converting text 187901
# Converting text 188001
# Converting text 188101
# Converting text 188201
# Converting text 188301
# Converting text 188401
# Converting text 188501
# Converting text 188601
# Converting text 188701
# Converting text 188801
# Converting text 188901
# Converting text 189001
# Converting text 189101
# Converting text 189201
# Converting text 189301
# Converting text 189401
# Converting text 189501
# Converting text 189601
# Converting text 189701
# Converting text 189801
# Converting text 189901
# Converting text 190001
# Converting text 190101
# Converting text 190201
# Converting text 190301
# Converting text 190401
# Converting text 190501
# Converting text 190601
# Converting text 190701
# Converting text 190801
# Converting text 190901
# Converting text 191001
# Converting text 191101
# Converting text 191201
# Converting text 191301
# Converting text 191401
# Converting text 191501
# Converting text 191601
# Converting text 191701
# Converting text 191801
# Converting text 191901
# Converting text 192001
# Converting text 192101
# Converting text 192201
# Converting text 192301
# Converting text 192401
# Converting text 192501
# Converting text 192601
# Converting text 192701
# Converting text 192801
# Converting text 192901
# Converting text 193001
# Converting text 193101
# Converting text 193201
# Converting text 193301
# Converting text 193401
# Converting text 193501
# Converting text 193601
# Converting text 193701
# Converting text 193801
# Converting text 193901
# Converting text 194001
# Converting text 194101
# Converting text 194201
# Converting text 194301
# Converting text 194401
# Converting text 194501
# Converting text 194601
# Converting text 194701
# Converting text 194801
# Converting text 194901
# Converting text 195001
# Converting text 195101
# Converting text 195201
# Converting text 195301
# Converting text 195401
# Converting text 195501
# Converting text 195601
# Converting text 195701
# Converting text 195801
# Converting text 195901
# Converting text 196001
# Converting text 196101
# Converting text 196201
# Converting text 196301
# Converting text 196401
# Converting text 196501
# Converting text 196601
# Converting text 196701
# Converting text 196801
# Converting text 196901
# Converting text 197001
# Converting text 197101
# Converting text 197201
# Converting text 197301
# Converting text 197401
# Converting text 197501
# Converting text 197601
# Converting text 197701
# Converting text 197801
# Converting text 197901
# Converting text 198001
# Converting text 198101
# Converting text 198201
# Converting text 198301
# Converting text 198401
# Converting text 198501
# Converting text 198601
# Converting text 198701
# Converting text 198801
# Converting text 198901
# Converting text 199001
# Converting text 199101
# Converting text 199201
# Converting text 199301
# Converting text 199401
# Converting text 199501
# Converting text 199601
# Converting text 199701
# Converting text 199801
# Converting text 199901
# Converting text 200001
# Converting text 200101
# Converting text 200201
# Converting text 200301
# Converting text 200401
# Converting text 200501
# Converting text 200601
# Converting text 200701
# Converting text 200801
# Converting text 200901
# Converting text 201001
# Converting text 201101
# Converting text 201201
# Converting text 201301
# Converting text 201401
# Converting text 201501
# Converting text 201601
# Converting text 201701
# Converting text 201801
# Converting text 201901
# Converting text 202001
# Converting text 202101
# Converting text 202201
# Converting text 202301
# Converting text 202401
# Converting text 202501
# Converting text 202601
# Converting text 202701
# Converting text 202801
# Converting text 202901
# Converting text 203001
# Converting text 203101
# Converting text 203201
# Converting text 203301
# Converting text 203401
# Converting text 203501
# Converting text 203601
# Converting text 203701
# Converting text 203801
# Converting text 203901
# Converting text 204001
# Converting text 204101
# Converting text 204201
# Converting text 204301
# Converting text 204401
# Converting text 204501
# Converting text 204601
# Converting text 204701
# Converting text 204801
# Converting text 204901
# Converting text 205001
# Converting text 205101
# Converting text 205201
# Converting text 205301
# Converting text 205401
# Converting text 205501
# Converting text 205601
# Converting text 205701
# Converting text 205801
# Converting text 205901
# Converting text 206001
# Converting text 206101
# Converting text 206201
# Converting text 206301
# Converting text 206401
# Converting text 206501
# Converting text 206601
# Converting text 206701
# Converting text 206801
# Converting text 206901
# Converting text 207001
# Converting text 207101
# Converting text 207201
# Converting text 207301
# Converting text 207401
# Converting text 207501
# Converting text 207601
# Converting text 207701
# Converting text 207801
# Converting text 207901
# Converting text 208001
# Converting text 208101
# Converting text 208201
# Converting text 208301
# Converting text 208401
# Converting text 208501
# Converting text 208601
# Converting text 208701
# Converting text 208801
# Converting text 208901
# Converting text 209001
# Converting text 209101
# Converting text 209201
# Converting text 209301
# Converting text 209401
# Converting text 209501
# Converting text 209601
# Converting text 209701
# Converting text 209801
# Converting text 209901
# Converting text 210001
# Converting text 210101
# Converting text 210201
# Converting text 210301
# Converting text 210401
# Converting text 210501
# Converting text 210601
# Converting text 210701
# Converting text 210801
# Converting text 210901
# Converting text 211001
# Converting text 211101
# Converting text 211201
# Converting text 211301
# Converting text 211401
# Converting text 211501
# Converting text 211601
# Converting text 211701
# Converting text 211801
# Converting text 211901
# Converting text 212001
# Converting text 212101
# Converting text 212201
# Converting text 212301
# Converting text 212401
# Converting text 212501
# Converting text 212601
# Converting text 212701
# Converting text 212801
# Converting text 212901
# Converting text 213001
# Converting text 213101
# Converting text 213201
# Converting text 213301
# Converting text 213401
# ...
# Converting text 201501
# Converting text 201601
# Converting text 201701
# Converting text 201801
# Converting text 201901
# Converting text 202001
# Converting text 202101
# Converting text 202201
# Converting text 202301
# Converting text 202401
# Converting text 202501
# Converting text 202601
# Converting text 202701
# Converting text 202801
# Converting text 202901
# Converting text 203001
# Converting text 203101
# Converting text 203201
# Converting text 203301
# Converting text 203401
# Converting text 203501
# Converting text 203601
# Converting text 203701
# Converting text 203801
# Converting text 203901
# Converting text 204001
# Converting text 204101
# Converting text 204201
# Converting text 204301
# Converting text 204401
# Converting text 204501
# Converting text 204601
# Converting text 204701
# Converting text 204801
# Converting text 204901
# Converting text 205001
# Converting text 205101
# Converting text 205201
# Converting text 205301
# Converting text 205401
# Converting text 205501
# Converting text 205601
# Converting text 205701
# Converting text 205801
# Converting text 205901
# Converting text 206001
# Converting text 206101
# Converting text 206201
# Converting text 206301
# Converting text 206401
# Converting text 206501
# Converting text 206601
# Converting text 206701
# Converting text 206801
# Converting text 206901
# Converting text 207001
# Converting text 207101
# Converting text 207201
# Converting text 207301
# Converting text 207401
# Converting text 207501
# Converting text 207601
# Converting text 207701
# Converting text 207801
# Converting text 207901
# Converting text 208001
# Converting text 208101
# Converting text 208201
# Converting text 208301
# Converting text 208401
# Converting text 208501
# Converting text 208601
# Converting text 208701
# Converting text 208801
# Converting text 208901
# Converting text 209001
# Converting text 209101
# Converting text 209201
# Converting text 209301
# Converting text 209401
# Converting text 209501
# Converting text 209601
# Converting text 209701
# Converting text 209801
# Converting text 209901
# Converting text 210001
# Converting text 210101
# Converting text 210201
# Converting text 210301
# Converting text 210401
# Converting text 210501
# Converting text 210601
# Converting text 210701
# Converting text 210801
# Converting text 210901
# Converting text 211001
# Converting text 211101
# Converting text 211201
# Converting text 211301
# Converting text 211401
# Converting text 211501
# Converting text 211601
# Converting text 211701
# Converting text 211801
# Converting text 211901
# Converting text 212001
# Converting text 212101
# Converting text 212201
# Converting text 212301
# Converting text 212401
# Converting text 212501
# Converting text 212601
# Converting text 212701
# Converting text 212801
# Converting text 212901
# Converting text 213001
# Converting text 213101
# Converting text 213201
# Converting text 213301
# Converting text 213401
# Converting text 213501
# Converting text 213601
# Converting text 213701
# Converting text 213801
# Converting text 213901
# Converting text 214001
# Converting text 214101
# Converting text 214201
# Converting text 214301
# Converting text 214401
# Converting text 214501
# Converting text 214601
# Converting text 214701
# Converting text 214801
# Converting text 214901
# Converting text 215001
# Converting text 215101
# Converting text 215201
# Converting text 215301
# Converting text 215401
# Converting text 215501
# Converting text 215601
# Converting text 215701
# Converting text 215801
# Converting text 215901
# Converting text 216001
# Converting text 216101
# Converting text 216201
# Converting text 216301
# Converting text 216401
# Converting text 216501
# Converting text 216601
# Converting text 216701
# Converting text 216801
# Converting text 216901
# Converting text 217001
# Converting text 217101
# Converting text 217201
# Converting text 217301
# Converting text 217401
# Converting text 217501
# Converting text 217601
# Converting text 217701
# Converting text 217801
# Converting text 217901
# Converting text 218001
# Converting text 218101
# Converting text 218201
# Converting text 218301
# Converting text 218401
# Converting text 218501
# Converting text 218601
# Converting text 218701
# Converting text 218801
# Converting text 218901
# Converting text 219001
# Converting text 219101
# Converting text 219201
# Converting text 219301
# Converting text 219401
# Converting text 219501
# Converting text 219601
# Converting text 219701
# Converting text 219801
# Converting text 219901
# Converting text 220001
# Converting text 220101
# Converting text 220201
# Converting text 220301
# Converting text 220401
# Converting text 220501
# Converting text 220601
# Converting text 220701
# Converting text 220801
# Converting text 220901
# Converting text 221001
# Converting text 221101
# Converting text 221201
# Converting text 221301
# Converting text 221401
# Converting text 221501
# Converting text 221601
# Converting text 221701
# Converting text 221801
# Converting text 221901
# Converting text 222001
# Converting text 222101
# Converting text 222201
# Converting text 222301
# Converting text 222401
# Converting text 222501
# Converting text 222601
# Converting text 222701
# Converting text 222801
# Converting text 222901
# Converting text 223001
# Converting text 223101
# Converting text 223201
# Converting text 223301
# Converting text 223401
# Converting text 223501
# Converting text 223601
# Converting text 223701
# Converting text 223801
# Converting text 223901
# Converting text 224001
# Converting text 224101
# Converting text 224201
# Converting text 224301
# Converting text 224401
# Converting text 224501
# Converting text 224601
# Converting text 224701
# Converting text 224801
# Converting text 224901
# Converting text 225001
# Converting text 225101
# Converting text 225201
# Converting text 225301
# Converting text 225401
# Converting text 225501
# Converting text 225601
# Converting text 225701
# Converting text 225801
# Converting text 225901
# Converting text 226001
# Converting text 226101
# Converting text 226201
# Converting text 226301
# Converting text 226401
# Converting text 226501
# Converting text 226601
# Converting text 226701
# Converting text 226801
# Converting text 226901
# Converting text 227001
# Converting text 227101
# Converting text 227201
# Converting text 227301
# Converting text 227401
# Converting text 227501
# Converting text 227601
# Converting text 227701
# Converting text 227801
# Converting text 227901
# Converting text 228001
# Converting text 228101
# Converting text 228201
# Converting text 228301
# Converting text 228401
# Converting text 228501
# Converting text 228601
# Converting text 228701
# Converting text 228801
# Converting text 228901
# Converting text 229001
# Converting text 229101
# Converting text 229201
# Converting text 229301
# Converting text 229401
# Converting text 229501
# Converting text 229601
# Converting text 229701
# Converting text 229801
# Converting text 229901
# Converting text 230001
# Converting text 230101
# Converting text 230201
# Converting text 230301
# Converting text 230401
# Converting text 230501
# Converting text 230601
# Converting text 230701
# Converting text 230801
# Converting text 230901
# Converting text 231001
# Converting text 231101
# Converting text 231201
# Converting text 231301
# Converting text 231401
# Converting text 231501
# Converting text 231601
# Converting text 231701
# Converting text 231801
# Converting text 231901
# Converting text 232001
# Converting text 232101
# Converting text 232201
# Converting text 232301
# Converting text 232401
# Converting text 232501
# Converting text 232601
# Converting text 232701
# Converting text 232801
# Converting text 232901
# Converting text 233001
# Converting text 233101
# Converting text 233201
# Converting text 233301
# Converting text 233401
# Converting text 233501
# Converting text 233601
# Converting text 233701
# Converting text 233801
# Converting text 233901
# Converting text 234001
# Converting text 234101
# Converting text 234201
# Converting text 234301
# Converting text 234401
# Converting text 234501
# Converting text 234601
# Converting text 234701
# Converting text 234801
# Converting text 234901
# Converting text 235001
# Converting text 235101
# Converting text 235201
# Converting text 235301
# Converting text 235401
# Converting text 235501
# Converting text 235601
# Converting text 235701
# Converting text 235801
# Converting text 235901
# Converting text 236001
# Converting text 236101
# Converting text 236201
# Converting text 236301
# Converting text 236401
# Converting text 236501
# Converting text 236601
# Converting text 236701
# Converting text 236801
# Converting text 236901
# Converting text 237001
# Converting text 237101
# Converting text 237201
# Converting text 237301
# Converting text 237401
# Converting text 237501
# Converting text 237601
# Converting text 237701
# Converting text 237801
# Converting text 237901
# Converting text 238001
# Converting text 238101
# Converting text 238201
# Converting text 238301
# Converting text 238401
# Converting text 238501
# Converting text 238601
# Converting text 238701
# Converting text 238801
# Converting text 238901
# Converting text 239001
# Converting text 239101
# Converting text 239201
# Converting text 239301
# Converting text 239401
# Converting text 239501
# Converting text 239601
# Converting text 239701
# Converting text 239801
# Converting text 239901
# Converting text 240001
# Converting text 240101
# Converting text 240201
# Converting text 240301
# Converting text 240401
# Converting text 240501
# Converting text 240601
# Converting text 240701
# Converting text 240801
# Converting text 240901
# Converting text 241001
# Converting text 241101
# Converting text 241201
# Converting text 241301
# Converting text 241401
# Converting text 241501
# Converting text 241601
# Converting text 241701
# Converting text 241801
# Converting text 241901
# Converting text 242001
# Converting text 242101
# Converting text 242201
# Converting text 242301
# Converting text 242401
# Converting text 242501
# Converting text 242601
# Converting text 242701
# Converting text 242801
# Converting text 242901
# Converting text 243001
# Converting text 243101
# Converting text 243201
# Converting text 243301
# Converting text 243401
# Converting text 243501
# Converting text 243601
# Converting text 243701
# Converting text 243801
# Converting text 243901
# Converting text 244001
# Converting text 244101
# Converting text 244201
# Converting text 244301
# Converting text 244401
# Converting text 244501
# Converting text 244601
# Converting text 244701
# Converting text 244801
# Converting text 244901
# Converting text 245001
# Converting text 245101
# Converting text 245201
# Converting text 245301
# Converting text 245401
# Converting text 245501
# Converting text 245601
# Converting text 245701
# Converting text 245801
# Converting text 245901
# Converting text 246001
# Converting text 246101
# Converting text 246201
# Converting text 246301
# Converting text 246401
# Converting text 246501
# Converting text 246601
# Converting text 246701
# Converting text 246801
# Converting text 246901
# Converting text 247001
# Converting text 247101
# Converting text 247201
# Converting text 247301
# Converting text 247401
# Converting text 247501
# Converting text 247601
# Converting text 247701
# Converting text 247801
# Converting text 247901
# Converting text 248001
# Converting text 248101
# Converting text 248201
# Converting text 248301
# Converting text 248401
# Converting text 248501
# Converting text 248601
# Converting text 248701
# Converting text 248801
# Converting text 248901
# Converting text 249001
# Converting text 249101
# Converting text 249201
# Converting text 249301
# Converting text 249401
# Converting text 249501
# Converting text 249601
# Converting text 249701
# Converting text 249801
# Converting text 249901
# Converting text 250001
# Converting text 250101
# Converting text 250201
# Converting text 250301
# Converting text 250401
# Converting text 250501
# Converting text 250601
# Converting text 250701
# Converting text 250801
# Converting text 250901
# Converting text 251001
# Converting text 251101
# Converting text 251201
# Converting text 251301
# Converting text 251401
# Converting text 251501
# Converting text 251601
# Converting text 251701
# Converting text 251801
# Converting text 251901
# Converting text 252001
# Converting text 252101
# Converting text 252201
# Converting text 252301
# Converting text 252401
# Converting text 252501
# Converting text 252601
# Converting text 252701
# Converting text 252801
# Converting text 252901
# Converting text 253001
# Converting text 253101
# Converting text 253201
# Converting text 253301
# Converting text 253401
# Converting text 253501
# Converting text 253601
# Converting text 253701
# Converting text 253801
# Converting text 253901
# Converting text 254001
# Converting text 254101
# Converting text 254201
# Converting text 254301
# Converting text 254401
# Converting text 254501
# Converting text 254601
# Converting text 254701
# Converting text 254801
# Converting text 254901
# Converting text 255001
# Converting text 255101
# Converting text 255201
# Converting text 255301
# Converting text 255401
# Converting text 255501
# Converting text 255601
# Converting text 255701
# Converting text 255801
# Converting text 255901
# Converting text 256001
# Converting text 256101
# Converting text 256201
# Converting text 256301
# Converting text 256401
# Converting text 256501
# Converting text 256601
# Converting text 256701
# Converting text 256801
# Converting text 256901
# Converting text 257001
# Converting text 257101
# Converting text 257201
# Converting text 257301
# Converting text 257401
# Converting text 257501
# Converting text 257601
# Converting text 257701
# Converting text 257801
# Converting text 257901
# Converting text 258001
# Converting text 258101
# Converting text 258201
# Converting text 258301
# Converting text 258401
# Converting text 258501
# Converting text 258601
# Converting text 258701
# Converting text 258801
# Converting text 258901
# Converting text 259001
# Converting text 259101
# Converting text 259201
# Converting text 259301
# Converting text 259401
# Converting text 259501
# Converting text 259601
# Converting text 259701
# Converting text 259801
# Converting text 259901
# Converting text 260001
# Converting text 260101
# Converting text 260201
# Converting text 260301
# Converting text 260401
# Converting text 260501
# Converting text 260601
# Converting text 260701
# Converting text 260801
# Converting text 260901
# Converting text 261001
# Converting text 261101
# Converting text 261201
# Converting text 261301
# Converting text 261401
# Converting text 261501
# Converting text 261601
# Converting text 261701
# Converting text 261801
# Converting text 261901
# Converting text 262001
# Converting text 262101
# Converting text 262201
# Converting text 262301
# Converting text 262401
# Converting text 262501
# Converting text 262601
# Converting text 262701
# Converting text 262801
# Converting text 262901
# Converting text 263001
# Converting text 263101
# Converting text 263201
# Converting text 263301
# Converting text 263401
# Converting text 263501
# Converting text 263601
# Converting text 263701
# Converting text 263801
# Converting text 263901
# Converting text 264001
# Converting text 264101
# Converting text 264201
# Converting text 264301
# Converting text 264401
# Converting text 264501
# Converting text 264601
# Converting text 264701
# Converting text 264801
# Converting text 264901
# Converting text 265001
# Converting text 265101
# Converting text 265201
# Converting text 265301
# Converting text 265401
# Converting text 265501
# Converting text 265601
# Converting text 265701
# Converting text 265801
# Converting text 265901
# Converting text 266001
# Converting text 266101
# Converting text 266201
# Converting text 266301
# Converting text 266401
# Converting text 266501
# Converting text 266601
# Converting text 266701
# Converting text 266801
# Converting text 266901
# Converting text 267001
# Converting text 267101
# Converting text 267201
# Converting text 267301
# Converting text 267401
# Converting text 267501
# Converting text 267601
# Converting text 267701
# Converting text 267801
# Converting text 267901
# Converting text 268001
# Converting text 268101
# Converting text 268201
# Converting text 268301
# Converting text 268401
# Converting text 268501
# Converting text 268601
# Converting text 268701
# Converting text 268801
# Converting text 268901
# Converting text 269001
# Converting text 269101
# Converting text 269201
# Converting text 269301
# Converting text 269401
# Converting text 269501
# Converting text 269601
# Converting text 269701
# Converting text 269801
# Converting text 269901
# Converting text 270001
# Converting text 270101
# Converting text 270201
# Converting text 270301
# Converting text 270401
# Converting text 270501
# Converting text 270601
# Converting text 270701
# Converting text 270801
# Converting text 270901

# %%
dataset.head()
# Out:
#    Unnamed: 0   PRODUCT  CATEGORY_ID  BRAND_ID  \
# 0           0  30024724      2060202      1900
# 1           1  30024724      2060202      1900
# 2           2  30024725      2060202      1900
# 3           3  30024727      2060101      1900
# 4           4  30024727      2060101      1900
#
#                                 CATEGORY_NAME            BRAND_NAME    TYPE  \
# 0  PRINTERS LASER                              Kyocera               REVIEW
# 1  PRINTERS LASER                              Kyocera               REVIEW
# 2  PRINTERS LASER                              Kyocera               REVIEW
# 3  ALL-IN-ONE LASER                            Kyocera               REVIEW
# 4  ALL-IN-ONE LASER                            Kyocera               REVIEW
#
#                                              SUBJECT  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  С такой вроде бы навороченной техникой все смо...
# 4                                                NaN
#
#                                                 TEXT        POSTED_DATE  \
# 0  Что особенно ценно - при профилактике принтера...  23.10.16 22:26:00
# 1  Он у нас три месяца в офисе стоит уже - большо...  17.04.16 11:17:42
# 2  Просто небо и земля с тем принтером, который у...  15.04.16 20:22:47
# 3  У нас в кабинете недавно его поставили. Первое...  18.04.16 20:01:57
# 4  Очень многофункциональная штука.  Есть все нео...  23.04.16 12:03:39
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                            DRAWBACKS RECOMMENDED LIKES_COUNT  \
# 0  Рядом "на стол" не поставишь, место много зани...         1.0         2.0
# 1                                                NaN         NaN         0.0
# 2                                                NaN         NaN         0.0
# 3                                                NaN         NaN         0.0
# 4                                                NaN         NaN         1.0
#
#    DISLIKES_COUNT                                    BENEFITS_FILLED  \
# 0             0.0  хорошая скорость печати, двусторонняя печать, ...
# 1             2.0
# 2             1.0
# 3             0.0
# 4             0.0
#
#                                     DRAWBACKS_FILLED  \
# 0  Рядом "на стол" не поставишь, место много зани...
# 1
# 2
# 3
# 4
#
#                                          TEXT_FILLED  \
# 0  Что особенно ценно - при профилактике принтера...
# 1  Он у нас три месяца в офисе стоит уже - большо...
# 2  Просто небо и земля с тем принтером, который у...
# 3  У нас в кабинете недавно его поставили. Первое...
# 4  Очень многофункциональная штука.  Есть все нео...
#
#                                       TEXT_CONVERTED  \
# 0  что_CONJ особенно_ADVB ценно_ADJS при_PREP про...
# 1  он_NPRO у_PREP нас_NPRO три_NUMR месяца_NOUN в...
# 2  просто_PRCL небо_NOUN и_CONJ земля_NOUN с_PREP...
# 3  у_PREP нас_NPRO в_PREP кабинете_NOUN недавно_A...
# 4  очень_ADVB многофункциональная_ADJF штука_NOUN...
#
#                                   BENEFITS_CONVERTED  \
# 0  хорошая_ADJF скорость_NOUN печати_NOUN двустор...
# 1
# 2
# 3
# 4
#
#                                  DRAWBACKS_CONVERTED
# 0  рядом_NOUN на_PREP стол_NOUN не_PRCL поставишь...
# 1
# 2
# 3
# 4
#
# [5 rows x 22 columns]

# %%
dataset.to_csv("checkpoint/reviews_converted.csv", index=False)

# %% [markdown]
# # Этап 2. Отбор N-грам
#
# Идея следующая - отобрать n-грамы, для которых значение tf-idf будет выше прочих n-грам текстов о этом товаре (такие n-грамы должны упоминаться относительно часто). После этого можно будет объединить n-грамы и построить по ним текст, но это - следующий этап

# %%
import pandas as pd
dataset = pd.read_csv("checkpoint/reviews_converted.csv")

# %% [markdown]
# Выберем наиболее часто встречаемый продукт (а также следующий за ним)

# %%
from scipy.stats import mode
import numpy as np

product = np.array(dataset["PRODUCT"])
top_product = mode(product)

# %%
top_product = top_product.mode[0]

# %%
top_product
# Out:
# 10006894

# %%
top_product = 10006894

# %% [markdown]
# Далее применим только относящуюся к этому продукту часть датасета

# %%
subdataset_index = dataset["PRODUCT"] == top_product
subdataset = dataset.loc[subdataset_index, ["PRODUCT", "TEXT_CONVERTED", "BENEFITS_CONVERTED", "DRAWBACKS_CONVERTED"]]

# %%
subdataset_texts = list(map(str,
                            list(subdataset["TEXT_CONVERTED"]) + 
                            list(subdataset["BENEFITS_CONVERTED"]) + 
                            list(subdataset["DRAWBACKS_CONVERTED"])))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# Построим несколько tf-idf (над отдельными "словами", биграммами и 3-граммами/4-граммами)

# %%
from itertools import chain

subdataset_sentences = []
for text in subdataset_texts:
    dot_del = text.split(".")
    for subtext in dot_del:
        subdataset_sentences += subtext.split(',')

# %%
print("Fitting TFIDF over 1-grams")
tfidf1 = TfidfVectorizer(ngram_range=(1,1)).fit(subdataset_sentences)
print("Fitting TFIDF over 2-grams")
tfidf2 = TfidfVectorizer(ngram_range=(2,2)).fit(subdataset_sentences)
print("Fitting TFIDF over 3-grams")
tfidf3 = TfidfVectorizer(ngram_range=(3,3)).fit(subdataset_sentences)
print("Fitting TFIDF over 4-grams")
tfidf4 = TfidfVectorizer(ngram_range=(4,4)).fit(subdataset_sentences)
# Out:
# Fitting TFIDF over 1-grams
# Fitting TFIDF over 2-grams
# Fitting TFIDF over 3-grams
# Fitting TFIDF over 4-grams

# %%
top_product_reviews = subdataset.loc[subdataset["PRODUCT"] == top_product]

# %% [markdown]
# Определим функцию, принимающую на вход полученную от tfidf матрицу и tfidf и возвращающую имена фич tfidf, отсортированные по среднему (на этих текстах) значению фичи

# %%
def tfidf_order_features(tfidf, matrix):
    mean_features = np.asarray(matrix.mean(axis=0))[0]
    ordered_features = mean_features.argsort()[::-1]
    feature_names = tfidf.get_feature_names()
    result = []
    for feature in ordered_features:
        result.append(feature_names[feature])
    return np.array(result)

# %%
top_product_tfidf1 = tfidf1.transform(subdataset_sentences)
top_product_tfidf2 = tfidf2.transform(subdataset_sentences)
top_product_tfidf3 = tfidf3.transform(subdataset_sentences)
top_product_tfidf4 = tfidf4.transform(subdataset_sentences)

# %%
tfidf_order_features(tfidf1, top_product_tfidf1)[:10]
# Out:
# array(['nan', 'в_prep', 'не_prcl', 'и_conj', 'на_prep', 'нет_pred',
#        'большой_adjf', 'телевизор_noun', 'что_conj', 'очень_advb'],
#       dtype='<U27')

# %%
tfidf_order_features(tfidf2, top_product_tfidf2)[:20]
# Out:
# array(['их_npro нет_pred', 'этот_adjf телевизор_noun',
#        'большой_adjf экран_noun', 'очень_advb большой_adjf',
#        'и_conj не_prcl', 'дорогая_adjf доставка_noun', 'у_prep меня_npro',
#        'доступная_adjf цена_noun', 'пришлось_verb продать_infn',
#        'а_conj так_conj', 'за_prep такие_adjf', 'такие_adjf деньги_noun',
#        'хорошее_adjf качество_noun', 'на_prep нем_adjs',
#        'очень_advb дорого_advb', 'всем_adjf рекомендую_verb',
#        'у_prep нас_npro', 'не_prcl обнаружил_verb', 'на_prep стену_noun',
#        'так_conj как_conj'],
#       dtype='<U42')

# %%
tfidf_order_features(tfidf3, top_product_tfidf3)[:30]
# Out:
# array(['за_prep такие_adjf деньги_noun',
#        'очень_advb доступный_adjf телек_noun',
#        'за_prep такую_adjf цену_noun', 'большой_adjf и_conj цветной_adjf',
#        'не_prcl поместился_verb в_prep',
#        'остался_verb без_prep квартиры_noun',
#        'цветной_adjf есть_intj пульт_noun',
#        'очень_advb хороший_adjf телевизор_noun',
#        'судя_grnd по_prep отзывам_noun', 'за_prep свои_adjf деньги_noun',
#        'цветной_adjf и_conj большой_adjf',
#        'сделан_prts в_prep россии_noun',
#        'вписался_verb в_prep интерьер_noun',
#        'хорошее_adjf качество_noun картинки_noun',
#        'у_prep нас_npro в_prep', 'купить_infn этот_adjf телевизор_noun',
#        'не_prcl могу_verb настроить_infn',
#        'телевизор_noun за_prep свои_adjf', 'не_prcl знаю_verb что_conj',
#        'продал_verb квартиру_noun купил_verb',
#        'цена_noun это_prcl его_npro', 'это_prcl его_npro основной_adjf',
#        'страна_noun производитель_noun россия_noun',
#        'в_prep ипотеку_noun на_prep', 'кнопка_noun плюс_conj на_prep',
#        'соотношение_noun цена качество_noun',
#        'берите_verb не_prcl пожалеете_verb', 'в_prep том_adjf что_conj',
#        'чтобы_conj купить_infn этот_adjf', 'нет_pred в_prep наличии_noun'],
#       dtype='<U59')

# %%
tfidf_order_features(tfidf4, top_product_tfidf4)[:40]
# Out:
# array(['цена_noun это_prcl его_npro основной_adjf',
#        'телевизор_noun за_prep свои_adjf деньги_noun',
#        'удобно_advb лежит_verb в_prep руке_noun',
#        'на_prep завтраках_noun в_prep школе_noun',
#        'в_prep описании_noun одни_adjf плюсы_noun',
#        'дешёвый_adjf могут_verb купить_infn все_adjf',
#        'тем_noun более_advb стоит_verb копейки_noun',
#        'я_npro думал_verb телевизор_noun водонепроницаем_adjs',
#        'батарейки_noun от_prep пульта_noun дорого_advb',
#        'теперь_advb придётся_verb открывать_infn кинотеатр_noun',
#        'мало_advb почек_noun для_prep оплаты_noun',
#        'работает_verb от_prep сети_noun вольт_noun',
#        'станции_noun в_prep форточку_noun протянули_verb',
#        'она_noun оторваться_infn не_prcl может',
#        'ловит_verb бесплатные_adjf цифровые_adjf каналы_noun',
#        'демократичная_adjf цена_noun неплохое_adjf качество_noun',
#        'пришлось_verb продать_infn все_adjf золото_noun',
#        'в_prep целом_noun очень_advb хороший_adjf',
#        'тоже_advb не_prcl без_prep них_npro',
#        'очень_advb долго_advb собирали_verb деньги_noun',
#        'пришлось_verb снести_infn несущие_adjf стены_noun',
#        'только_prcl они_npro и_conj есть_intj',
#        'большой_adjf с_prep изогнутым_adjf экраном_noun',
#        'не_prcl сворачивается_verb в_prep трубу_noun',
#        'для_prep своих_adjf характеристик_noun недорог_adjs',
#        'отличный_adjf телевизор_noun крутая_adjf картинка_noun',
#        'когда_advb включаю_verb маки_noun распускаются_verb',
#        'клевый_adjf телек_noun очень_advb нравится_verb',
#        'классно_advb горит_verb в_prep костре_noun',
#        'отобрала_verb жена_noun при_prep разводе_noun',
#        'качество_noun от_prep самсунг_noun наилучшее_adjf',
#        'долго_advb везли_verb до_prep мадрида_noun',
#        'тяжёлый_adjf кг_noun пластмассового_adjf веса_noun',
#        'тем_noun более_advb даже_prcl ген',
#        'жена_noun подарила_verb люблю_verb её_adjf',
#        'у_prep него_npro своя_adjf гравитация_noun',
#        'на_prep фотографии_noun очень_advb красивый_adjf',
#        'нельзя_pred подвесить_infn на_prep стену_noun',
#        'прожорливые_adjf электичество_noun только_prcl давай_verb',
#        'произведён_prts не_prcl в_prep россии_noun'],
#       dtype='<U76')

# %% [markdown]
# Видим, что с 3-граммами и 4-граммами видны признаки, из которых можно извлечь тексты (но необходимо будет объединить многие признаки и ввести фильтрацию).

# %%
import re

ignorance_filter = lambda text: bool(re.match(".*prep", text)) or \
    bool(re.match(".*infn", text)) or \
    bool(re.match(".*verb", text))
feature_filter = lambda text: bool(re.match(".*adjf .*noun", text)) and not ignorance_filter(text)

# %%
list(filter(feature_filter, tfidf_order_features(tfidf3, top_product_tfidf3)))[:20]
# Out:
# ['очень_advb доступный_adjf телек_noun',
#  'цветной_adjf есть_intj пульт_noun',
#  'очень_advb хороший_adjf телевизор_noun',
#  'хорошее_adjf качество_noun картинки_noun',
#  'кривые_noun задние_adjf ножки_noun',
#  'реально_adjs крутое_adjf изображение_noun',
#  'хоршая_adjf картинка_noun изогнутый_adjf',
#  'нет_pred оранжевого_adjf корпуса_noun',
#  'большой_adjf чёткий_adjf экран_noun',
#  'дешевле_comp некоторых_adjf квартир_noun',
#  'хорошее_adjf качество_noun сборки_noun',
#  'хороший_adjf бюджетный_adjf телевизор_noun',
#  'нет_pred настенного_adjf крепления_noun',
#  'отличное_adjf антикризисное_adjf предложение_noun',
#  'слишком_advb дорогая_adjf доставка_noun',
#  'слишком_advb маленький_adjf размер_noun',
#  'супер_adjf хороший_adjf телевизер_noun',
#  'этот_adjf тв_noun и_conj',
#  'не_prcl плохой_adjf телик_noun',
#  'такую_adjf цену_noun нет_pred']

# %%
import pickle as pcl

with open("checkpoint/tfidf2.pkl", "wb") as target:
    pcl.dump(tfidf2, target)
with open("checkpoint/tfidf3.pkl", "wb") as target:
    pcl.dump(tfidf3, target)
with open("checkpoint/tfidf4.pkl", "wb") as target:
    pcl.dump(tfidf4, target)

# %%
top_features_tfidf2 = np.array(list(
    filter(feature_filter, tfidf_order_features(tfidf2, top_product_tfidf2)))[:50]
)
np.save("checkpoint/top-tfidf2.npy", top_features_tfidf2)
top_features_tfidf3 = np.array(list(
    filter(feature_filter, tfidf_order_features(tfidf3, top_product_tfidf3)))[:50]
)
np.save("checkpoint/top-tfidf3.npy", top_features_tfidf3)
top_features_tfidf4 = np.array(list(
    filter(feature_filter, tfidf_order_features(tfidf4, top_product_tfidf4)))[:50]
)
np.save("checkpoint/top-tfidf4.npy", top_features_tfidf4)

# %% [markdown]
# # Кластеризация и отбор N-грам
#
# Для объединения N-грам применим word mover distance (предварительно обучив word2vec, т.к. использование предобученной модели от rusvectores потребует, как минимум, адаптации)

# %%
import pandas as pd
dataset = pd.read_csv("checkpoint/reviews_converted.csv")

all_tokens = list(map(lambda text: str(text).lower().split(" "),
                      list(dataset["TEXT_CONVERTED"]) + 
                      list(dataset["BENEFITS_CONVERTED"]) + 
                      list(dataset["DRAWBACKS_CONVERTED"])))

# %%
from gensim.models import Word2Vec

word2vec = Word2Vec(all_tokens)

# %%
word2vec.wv.save_word2vec_format('checkpoint/word2vec.bin', binary=True)

# %%
from gensim.models import KeyedVectors

word2vec = KeyedVectors.load_word2vec_format('checkpoint/word2vec.bin', binary=True)

# %%
from scipy.spatial.distance import cosine

def distance(doc1, doc2, word2vec):
    doc1vec = np.array([np.zeros([word2vec.vector_size])] + 
                       [word2vec[token] for token in doc1.split(" ") if token in word2vec]).sum(axis=0)
    doc2vec = np.array([np.zeros([word2vec.vector_size])] + 
                       [word2vec[token] for token in doc2.split(" ") if token in word2vec]).sum(axis=0)
    diff = doc1vec - doc2vec
    return cosine(doc1vec, doc2vec)

# %%
import pickle

with open("checkpoint/tfidf2.pkl", "rb") as src:
    tfidf2 = pickle.load(src)
with open("checkpoint/tfidf3.pkl", "rb") as src:
    tfidf3 = pickle.load(src)
with open("checkpoint/tfidf4.pkl", "rb") as src:
    tfidf4 = pickle.load(src)

# %%
import numpy as np

top_product_tfidf2 = np.load("checkpoint/top-tfidf2.npy")
top_product_tfidf3 = np.load("checkpoint/top-tfidf3.npy")
top_product_tfidf4 = np.load("checkpoint/top-tfidf4.npy")

# %%
top_features = list(set(top_product_tfidf2.tolist() + 
                        top_product_tfidf3.tolist() + 
                        top_product_tfidf4.tolist()))
top_features.sort()

# %%
distances = np.zeros([len(top_features), len(top_features)])
for i, feature1 in enumerate(top_features):
    for j, feature2 in enumerate(top_features):
        features_distance = distance(feature1, feature2, word2vec)
        distances[i, j] = features_distance
        distances[j, i] = features_distance

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(0.2, min_samples=1, metric="precomputed")
clusters = dbscan.fit_predict(distances)

items = {}
for cluster, feature in zip(clusters, top_features):
    items[cluster] = items.get(cluster, []) + [feature]

# %%
choosen_ngrams = []
for key, values in items.items():
    values_indices = np.array([top_features.index(val) for val in values])
    if len(values) < 2:
        continue
    values_distances = distances[values_indices, :][:, values_indices]
    index_mean_distances = np.zeros([len(values_indices)])
    for i in range(0, len(values_indices)):
        index_mean_distances[i] = np.delete(values_distances[i], i, axis=0).mean()
    choosen_ngram = values[index_mean_distances.argmin()]
    print(key, choosen_ngram)
    choosen_ngrams.append(choosen_ngram)
# Out:
# 1 хорошее_adjf качество_noun картинки_noun
# 5 большой_adjf всю_adjf жизнь_noun
# 6 большой_adjf экран_noun цветное_adjf изображение_noun
# 8 отличный_adjf телевизор_noun крутая_adjf картинка_noun
# 16 громкий_adjf звук_noun
# 17 да_prcl не_prcl плохой_adjf телик_noun
# 18 этот_adjf телевизор_noun
# 20 доступная_adjf цена_noun
# 24 отображение_noun каждого_adjf цвета_noun и_conj
# 26 и_conj большой_adjf телек_noun норм_noun
# 28 супер_adjf качество_noun удобная_adjf
# 29 тяжёлый_adjf кг_noun пластмассового_adjf веса_noun
# 33 моё_adjf лицо_noun немного_advb
# 40 одни_adjf плюсы_noun
# 42 отличное_adjf антикризисное_adjf предложение_noun
# 52 эти_adjf деньги_noun
# 62 такую_adjf цену_noun их_npro нет_pred
# 66 упаковочная_adjf коробка_noun не_prcl
# 69 цветной_adjf есть_intj пульт_noun

# %% [markdown]
# Видим, что из собранных N-грам, похоже, можно собрать тексты. Но некоторые из них потребуется удалить или доработать.

# %%
np.save("checkpoint/chosen_ngrams.npy", np.array(choosen_ngrams))

# %% [markdown]
# # Сборка текста
#
# Запишем правила сборки итогового текста (воспользовавшись работающими с pos-тегами регулярными выражениями для правил расстановки препинания/удаления pos-тегов/обрезки текста)

# %%
import re

rules = [lambda text: re.sub("_adjf+ (\w+)_intj", ", \g<1>", text),
         lambda text: re.sub("_noun+ (\w+)_adjf", ", \g<1>", text),
         lambda text: re.sub("^\w+_conj", "", text),
         lambda text: re.sub("\w+_conj$", "", text),
         lambda text: re.sub("^\w+_pred", "", text),
         lambda text: re.sub("\w+_pred$", "", text),
         lambda text: re.sub("^\w+_precl", "", text),
         lambda text: re.sub("\w+_precl$", "", text),
         lambda text: re.sub("_[a-z]+", "", text),
         lambda text: text.strip()]

# %%
def apply_rules(rules, text):
    if isinstance(text, list):
        return [apply_rules(rules, item) for item in text]
    for rule in rules:
        text = rule(text)
    return text

# %%
choosen_ngrams = np.load("checkpoint/chosen_ngrams.npy")

apply_rules(rules, choosen_ngrams.tolist())
# Out:
# ['хорошее качество картинки',
#  'большой всю жизнь',
#  'большой экран, цветное изображение',
#  'отличный телевизор, крутая картинка',
#  'громкий звук',
#  'да не плохой телик',
#  'этот телевизор',
#  'доступная цена',
#  'отображение, каждого цвета',
#  'большой телек норм',
#  'супер качество, удобная',
#  'тяжёлый кг, пластмассового веса',
#  'моё лицо немного',
#  'одни плюсы',
#  'отличное антикризисное предложение',
#  'эти деньги',
#  'такую цену их',
#  'упаковочная коробка не',
#  'цветной, есть пульт']

# %% [markdown]
# Видим, что пункты образованы, но далеки от идеала.
#
# Возможно - стоит добавить n-грамы большей размерности и фильтровать их с помощью не только внутрикластерных расстояний, но и языковых моделей. Это, вероятно, убрало бы некоторые явно неверно обработанные результаты.
